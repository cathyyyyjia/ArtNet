# %% [markdown]
# # Initial Setup

# %%
from google.colab import drive
drive.mount('/gdrive')
# !ls /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# 'My Drive'  'Shared drives'

# %%
import os

BASE_PATH = '/gdrive/Shared drives/CSE599G1 Deep Learning Project/'
STYLE_PATH = BASE_PATH + 'images'
os.chdir(STYLE_PATH)
# !ls
os.chdir(BASE_PATH)
# Out:
# input  output  style

# %%
import torch
print('Version', torch.__version__)
print('CUDA enabled:', torch.cuda.is_available())
# Out:
# Version 1.3.1
# CUDA enabled: True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Download pretrained VGG19 Model
if "vgg19-d01eb7cb.pth" not in os.listdir(BASE_PATH+"models/"):
    # !wget -c https://s3-us-west-2.amazonaws.com/jcjohns-models/vgg19-d01eb7cb.pth
    # !cp vgg19-d01eb7cb.pth models/

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, models
import torch.optim as optim

from os.path import isfile, join
from copy import deepcopy
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # Define ArtNet

# %%
class ArtNet(nn.Module):
    def __init__(self):
        super(ArtNet, self).__init__()
        # use feature layers from VGG19
        model = models.vgg19(pretrained=True)
        model.load_state_dict(torch.load(MODEL_PATH), strict=False)
        self.artnet = deepcopy(model.features)
        # replace max pooling with avg pooling
        for idx, layer in self.artnet.named_children():
            if isinstance(layer, nn.MaxPool2d):
                self.artnet[int(idx)] = nn.AvgPool2d(kernel_size=2, stride=2)
        # lock gradient
        for param in self.artnet.parameters():
            param.requires_grad=False

    def get_features(self, x):
        features = {}
        layers = {
            '3': 'relu1_2',
            '8': 'relu2_2',
            '17' : 'relu3_3',
            '26' : 'relu4_3',
            '35' : 'relu5_3',
            '22' : 'relu4_2'
        }
        for idx, layer in self.artnet.named_children():
            x = layer(x)
            if idx in layers:
                if idx == '22':
                    features[layers[idx]] = x
                else:
                    B, C, H, W = x.shape
                    features[layers[idx]] = gram(x) / (H * W)
            if idx == '35':
                break
        return features

# %% [markdown]
# # Load Input Image and Style Image

# %%
# load image from given path
def load_image(image_path):
    return cv2.imread(image_path)

# show image
def show_image(image, title=None):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = np.array(image/255).clip(0,1)
    plt.figure()
    plt.imshow(image)
    if title != None:
        plt.title(title)

# convert image to tensor
def image_to_tensor(image):
    H, W, C = image.shape
    image_size = tuple([int((float(1024) / max([H,W])) * x) for x in [H, W]])
    transformer = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize(image_size),
        transforms.ToTensor()
    ])
    normalizer = transforms.Normalize([103.939, 116.779, 123.68],[1,1,1])
    tensor = normalizer(transformer(image)*255)
    tensor = tensor.unsqueeze(dim=0)
    return tensor

# convert tensor to image
def tensor_to_image(tensor):
    tensor = tensor.squeeze()
    transformer = transforms.Normalize([-103.939, -116.779, -123.68],[1,1,1])
    image = transformer(tensor)
    image = image.cpu().numpy().transpose(1, 2, 0) # C, H, W -> H, W, C
    return image

# %%
CONTENT_PATH = "./images/input/wave.jpg"
STYLE_PATH =  "./images/style/Hokusai - The Great Wave off Kanagawa.jpg"
MODEL_PATH = "./models/vgg19-d01eb7cb.pth"
OPTIMIZER = "adam" # "lbfgs"
MAX_ITER = 300
CONTENT_WEIGHT = 1
STYLE_WEIGHT = 1000
TV_WEIGHT = 0.001
PRESERVE_COLOR = False
PIXEL_CLIP = True

content_image = load_image(CONTENT_PATH)
style_image = load_image(STYLE_PATH)
show_image(content_image, title="Content Image")
show_image(style_image, title="Style Image")
content_tensor = image_to_tensor(content_image).to(device)
style_tensor = image_to_tensor(style_image).to(device)

# %% [markdown]
# # Define Loss Functions

# %%
# content loss
def content_loss(output_features, content_features):
    loss = F.mse_loss(output_features, content_features)
    return loss

# gram matrix
def gram(tensor):
    B, C, H, W = tensor.shape
    x = tensor.view(C, H*W)
    return torch.mm(x, x.t())

# style loss
def style_loss(output_features, style_feature):
    C1, C2 = output_features.shape
    loss = F.mse_loss(output_features, style_feature)
    loss /= C1 ** 2
    return loss

# total variation loss
def tv_loss(content_features):
    x = content_features[:,:,1:,:] - content_features[:,:,:-1,:]
    y = content_features[:,:,:,1:] - content_features[:,:,:,:-1]
    loss = torch.sum(torch.abs(x)) + torch.sum(torch.abs(y))
    return loss

# %% [markdown]
# # Style Transfer

# %%
class StyleTransfer():
    def __init__(self, content_image, style_image):
        self.content = content_image
        self.style = style_image
        self.output = content_image.clone().detach().to(device).requires_grad_(True)
        self.best = deepcopy(self.output)
        self.total_loss = 10e10

    def get_optimizer(self, option):
        if option == "lbfgs":
            opt = optim.LBFGS([self.output])
        elif option == "adam":
            opt = optim.Adam([self.output], lr=10)
        return opt

    def preserve_color(self):
        content = tensor_to_image(self.content.clone().detach())
        output = tensor_to_image(self.output.clone().detach())
        if PIXEL_CLIP:
            content = content.clip(0,255)
            output = output.clip(0,255)   
        H, W, _ = content.shape
        output = cv2.resize(output, dsize=(W, H), interpolation=cv2.INTER_CUBIC)
        output_gray = cv2.cvtColor(output, cv2.COLOR_BGR2GRAY) # extract the luminance of output image
        content_ = cv2.cvtColor(content, cv2.COLOR_BGR2YCrCb) # convert content image from BGR to YIQ/YCbCr
        content_[...,0] = output_gray # combine luminance and IQ/CbCr
        
        return cv2.cvtColor(content_, cv2.COLOR_YCrCb2BGR)

    def save_best_image(self, loss):
        # save best image with lowest total loss
        if loss < self.total_loss:
            self.total_loss = loss
            if PRESERVE_COLOR:
                self.best = self.preserve_color()
            else:
                self.best = tensor_to_image(self.output.clone().detach())
        return

    def save_image(self):
        # save self.best as best image in output folder
        style = STYLE_PATH.split("/")[-1].rstrip(".jpg") # style image name
        image_name = CONTENT_PATH.split("/")[-1].rstrip(".jpg") # content image name
        save_path = "./images/output/"+style+"-"+image_name
        if PRESERVE_COLOR:
            save_path += "-color" # preserve color version
        save_path += ".jpg"
        if PIXEL_CLIP:
            self.best = self.best.clip(0, 255)
        cv2.imwrite(save_path, self.best)
        return

    def transfer_style(self):
        content_layers = ['relu4_2']
        content_weights = {'relu4_2': 1.0} 
        style_layers = ['relu1_2', 'relu2_2', 'relu3_3', 'relu4_3', 'relu5_3']
        style_weights = {'relu1_2': 0.2, 'relu2_2': 0.2, 'relu3_3': 0.2, 'relu4_3': 0.2, 'relu5_3': 0.2}
        model = ArtNet().to(device)
        content_features = model.get_features(self.content)
        style_features = model.get_features(self.style)
        optimizer = self.get_optimizer(OPTIMIZER)
        i = [0]
        while i[0] < MAX_ITER:
            def closure():
                output_features = model.get_features(self.output)
                optimizer.zero_grad()
                c_loss = 0
                s_loss = 0
                for j in content_layers:
                    c_loss += content_weights[j] * content_loss(output_features[j], content_features[j])
                for j in style_layers:
                    s_loss += style_weights[j] * style_loss(output_features[j], style_features[j])
                c_loss = CONTENT_WEIGHT * c_loss
                s_loss = STYLE_WEIGHT * s_loss
                t_loss = TV_WEIGHT * tv_loss(self.output.clone().detach())
                total_loss = c_loss + s_loss + t_loss
                total_loss.backward(retain_graph=True)
                self.save_best_image(total_loss) # save best image

                i[0] += 1
                return total_loss
            
            optimizer.step(closure)
        
        self.save_image()
        show_image(self.best)
        plt.show()
        return

# %%
myStyleTransfer = StyleTransfer(content_tensor, style_tensor)
myStyleTransfer.transfer_style()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:07<00:00, 81.4MB/s]

# %%
# read file names to list
os.chdir('/gdrive/Shared drives/CSE599G1 Deep Learning Project/')
content_name = [f for f in os.listdir("./images/input/") if isfile(join("./images/input/", f))]
style_name = [f for f in os.listdir("./images/style/") if isfile(join("./images/style/", f))]
# print(content_name)
print(style_name)
# Out:
# ['Monet - Camille Monet On Her Deathbed.jpg', 'Picasso - The Dream.jpg', 'Rousseau - Myself.jpg', 'van Gogh - Starry Night.jpg', 'Gao Jianfu - Cotton Roses and Mandarin Ducks.jpg', 'Qi Baishi - Lotus Flowers and Wild Duck.jpg', 'Hokusai - The Great Wave off Kanagawa.jpg', 'Aoyama - Detective Conan.jpg', 'Monet - Haystack.jpg', "Monet - En Paysage dans l'ile Saint-Martin.jpg"]

# %%
# read current total loss

total_loss_dict = {}
f = open("./total_loss.csv", "r")
for line in f:
    key, total_loss = line.split(",")
    total_loss_dict[key] = float(total_loss)
f.close()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_PATH = "./models/vgg19-d01eb7cb.pth"
OPTIMIZER = "adam" # "lbfgs"
MAX_ITER = 300
CONTENT_WEIGHT = 1
STYLE_WEIGHT = 1000
TV_WEIGHT = 0.001
PIXEL_CLIP = True

for i in content_name:
  for j in style_name:
    CONTENT_PATH = "./images/input/" + i
    STYLE_PATH =  "./images/style/" + j
    file_name =  STYLE_PATH.split("/")[-1].rstrip(".jpg") + '-' + CONTENT_PATH.split("/")[-1].rstrip(".jpg")
    if file_name not in total_loss_dict:
        print("Generating output images", file_name + "...")
        content_image = load_image(CONTENT_PATH)
        style_image = load_image(STYLE_PATH)
        content_tensor = image_to_tensor(content_image).to(device)
        style_tensor = image_to_tensor(style_image).to(device)

        # not preserve color
        PRESERVE_COLOR = False
        myStyleTransfer = StyleTransfer(content_tensor, style_tensor)
        myStyleTransfer.transfer_style()  
        total_loss_dict[file_name] = myStyleTransfer.total_loss.cpu().detach()
        
        # preserve color
        PRESERVE_COLOR = True
        myStyleTransfer = StyleTransfer(content_tensor, style_tensor)
        myStyleTransfer.transfer_style()
        total_loss_dict[file_name+'-color'] = myStyleTransfer.total_loss.cpu().detach()

# %%
f = open("./total_loss.csv", "w")
for key, total_loss in total_loss_dict.items():
    f.write(key + "," + str(float(total_loss)) + "\n")
f.close()

# %%
# !cat ./total_loss.csv
# Out:
# Monet - Camille Monet On Her Deathbed-uw-cherry,77290.953125
# Monet - Camille Monet On Her Deathbed-uw-cherry-color,77290.953125
# Picasso - The Dream-uw-cherry,167316.78125
# Picasso - The Dream-uw-cherry-color,167316.78125
# Rousseau - Myself-uw-cherry,95196.0078125
# Rousseau - Myself-uw-cherry-color,95196.0078125
# van Gogh - Starry Night-uw-cherry,110918.3046875
# van Gogh - Starry Night-uw-cherry-color,110918.3046875
# Gao Jianfu - Cotton Roses and Mandarin Ducks-uw-cherry,130667.21875
# Gao Jianfu - Cotton Roses and Mandarin Ducks-uw-cherry-color,130667.21875
# Qi Baishi - Lotus Flowers and Wild Duck-uw-cherry,152211.046875
# Qi Baishi - Lotus Flowers and Wild Duck-uw-cherry-color,152211.046875
# Hokusai - The Great Wave off Kanagawa-uw-cherry,159260.453125
# Hokusai - The Great Wave off Kanagawa-uw-cherry-color,159260.453125
# Aoyama - Detective Conan-uw-cherry,300087.8125
# Aoyama - Detective Conan-uw-cherry-color,300087.8125
# Monet - Camille Monet On Her Deathbed-grumpy-cat,89060.34375
# Monet - Camille Monet On Her Deathbed-grumpy-cat-color,89060.34375
# Picasso - The Dream-grumpy-cat,123588.6875
# Picasso - The Dream-grumpy-cat-color,123588.6875
# Rousseau - Myself-grumpy-cat,94858.796875
# Rousseau - Myself-grumpy-cat-color,94858.796875
# van Gogh - Starry Night-grumpy-cat,117965.25
# van Gogh - Starry Night-grumpy-cat-color,117965.25
# Gao Jianfu - Cotton Roses and Mandarin Ducks-grumpy-cat,95378.84375
# Gao Jianfu - Cotton Roses and Mandarin Ducks-grumpy-cat-color,95378.84375
# Qi Baishi - Lotus Flowers and Wild Duck-grumpy-cat,109613.484375
# Qi Baishi - Lotus Flowers and Wild Duck-grumpy-cat-color,109613.484375
# Hokusai - The Great Wave off Kanagawa-grumpy-cat,164465.84375
# Hokusai - The Great Wave off Kanagawa-grumpy-cat-color,164465.84375
# Aoyama - Detective Conan-grumpy-cat,343541.78125
# Aoyama - Detective Conan-grumpy-cat-color,343541.78125
# Monet - Camille Monet On Her Deathbed-paris,79445.34375
# Monet - Camille Monet On Her Deathbed-paris-color,79445.34375
# Picasso - The Dream-paris,168469.265625
# Picasso - The Dream-paris-color,168469.265625
# Rousseau - Myself-paris,79785.25
# Rousseau - Myself-paris-color,79785.25
# van Gogh - Starry Night-paris,125564.203125
# van Gogh - Starry Night-paris-color,125564.203125
# Gao Jianfu - Cotton Roses and Mandarin Ducks-paris,90691.8984375
# Gao Jianfu - Cotton Roses and Mandarin Ducks-paris-color,90691.8984375
# Qi Baishi - Lotus Flowers and Wild Duck-paris,101333.5703125
# Qi Baishi - Lotus Flowers and Wild Duck-paris-color,101333.5703125
# Hokusai - The Great Wave off Kanagawa-paris,144853.96875
# Hokusai - The Great Wave off Kanagawa-paris-color,144853.96875
# Aoyama - Detective Conan-paris,296905.9375
# Aoyama - Detective Conan-paris-color,296905.9375
# Monet - Camille Monet On Her Deathbed-wave,70848.015625
# Monet - Camille Monet On Her Deathbed-wave-color,70848.015625
# Picasso - The Dream-wave,172040.765625
# Picasso - The Dream-wave-color,172040.765625
# Rousseau - Myself-wave,95835.8125
# Rousseau - Myself-wave-color,95835.8125
# van Gogh - Starry Night-wave,98550.1328125
# van Gogh - Starry Night-wave-color,98550.1328125
# Gao Jianfu - Cotton Roses and Mandarin Ducks-wave,87507.90625
# Gao Jianfu - Cotton Roses and Mandarin Ducks-wave-color,87507.90625
# Qi Baishi - Lotus Flowers and Wild Duck-wave,99723.1796875
# Qi Baishi - Lotus Flowers and Wild Duck-wave-color,99723.1796875
# Hokusai - The Great Wave off Kanagawa-wave,142869.78125
# Hokusai - The Great Wave off Kanagawa-wave-color,142869.78125
# Aoyama - Detective Conan-wave,316365.09375
# Aoyama - Detective Conan-wave-color,316365.09375
# Monet - Haystack-uw-cherry,96137.4453125
# Monet - Haystack-uw-cherry-color,99552.28125
# Monet - Haystack-grumpy-cat,87382.765625
# Monet - Haystack-grumpy-cat-color,88842.984375
# Monet - Haystack-paris,85496.453125
# Monet - Haystack-paris-color,85934.15625
# Monet - Haystack-wave,78944.90625
# Monet - Haystack-wave-color,80813.65625
# Monet - Camille Monet On Her Deathbed-seattle,85017.8359375
# Monet - Camille Monet On Her Deathbed-seattle-color,84223.578125
# Picasso - The Dream-seattle,159335.875
# Picasso - The Dream-seattle-color,149482.734375
# Rousseau - Myself-seattle,83210.609375
# Rousseau - Myself-seattle-color,84436.609375
# van Gogh - Starry Night-seattle,127280.0078125
# van Gogh - Starry Night-seattle-color,127250.34375
# Gao Jianfu - Cotton Roses and Mandarin Ducks-seattle,89669.875
# Gao Jianfu - Cotton Roses and Mandarin Ducks-seattle-color,87009.890625
# Qi Baishi - Lotus Flowers and Wild Duck-seattle,112197.078125
# Qi Baishi - Lotus Flowers and Wild Duck-seattle-color,113219.203125
# Hokusai - The Great Wave off Kanagawa-seattle,156102.25
# Hokusai - The Great Wave off Kanagawa-seattle-color,155582.546875
# Aoyama - Detective Conan-seattle,289894.5
# Aoyama - Detective Conan-seattle-color,286890.53125
# Monet - Haystack-seattle,82327.890625
# Monet - Haystack-seattle-color,82834.671875
# Monet - En Paysage dans l'ile Saint-Martin-uw-cherry,88306.84375
# Monet - En Paysage dans l'ile Saint-Martin-uw-cherry-color,88306.84375
# Monet - En Paysage dans l'ile Saint-Martin-grumpy-cat,89302.046875
# Monet - En Paysage dans l'ile Saint-Martin-grumpy-cat-color,89302.046875
# Monet - En Paysage dans l'ile Saint-Martin-paris,79286.7265625
# Monet - En Paysage dans l'ile Saint-Martin-paris-color,79286.7265625
# Monet - En Paysage dans l'ile Saint-Martin-wave,83514.3671875
# Monet - En Paysage dans l'ile Saint-Martin-wave-color,83514.3671875
# Monet - En Paysage dans l'ile Saint-Martin-seattle,74244.4609375
# Monet - En Paysage dans l'ile Saint-Martin-seattle-color,74244.4609375
# Monet - Camille Monet On Her Deathbed-Faroe Islands,89239.3125
# Monet - Camille Monet On Her Deathbed-Faroe Islands-color,89239.3125
# Picasso - The Dream-Faroe Islands,181212.75
# Picasso - The Dream-Faroe Islands-color,181212.75
# Rousseau - Myself-Faroe Islands,85289.5390625
# Rousseau - Myself-Faroe Islands-color,85289.5390625
# van Gogh - Starry Night-Faroe Islands,97191.9375
# van Gogh - Starry Night-Faroe Islands-color,97191.9375
# Gao Jianfu - Cotton Roses and Mandarin Ducks-Faroe Islands,97396.28125
# Gao Jianfu - Cotton Roses and Mandarin Ducks-Faroe Islands-color,97396.28125
# Qi Baishi - Lotus Flowers and Wild Duck-Faroe Islands,120355.25
# Qi Baishi - Lotus Flowers and Wild Duck-Faroe Islands-color,120355.25
# Hokusai - The Great Wave off Kanagawa-Faroe Islands,165312.15625
# Hokusai - The Great Wave off Kanagawa-Faroe Islands-color,165312.15625
# Aoyama - Detective Conan-Faroe Islands,323034.375
# Aoyama - Detective Conan-Faroe Islands-color,323034.375
# Monet - Haystack-Faroe Islands,94011.765625
# Monet - Haystack-Faroe Islands-color,94011.765625
# Monet - En Paysage dans l'ile Saint-Martin-Faroe Islands,84428.6875
# Monet - En Paysage dans l'ile Saint-Martin-Faroe Islands-color,84428.6875
# Monet - Camille Monet On Her Deathbed-Tulips,154713.09375
# Monet - Camille Monet On Her Deathbed-Tulips-color,154713.09375
# Picasso - The Dream-Tulips,226871.109375
# Picasso - The Dream-Tulips-color,226871.109375
# Rousseau - Myself-Tulips,137509.828125
# Rousseau - Myself-Tulips-color,137509.828125
# van Gogh - Starry Night-Tulips,140696.984375
# van Gogh - Starry Night-Tulips-color,140696.984375
# Gao Jianfu - Cotton Roses and Mandarin Ducks-Tulips,187552.625
# Gao Jianfu - Cotton Roses and Mandarin Ducks-Tulips-color,187552.625
# Qi Baishi - Lotus Flowers and Wild Duck-Tulips,230436.09375
# Qi Baishi - Lotus Flowers and Wild Duck-Tulips-color,230436.09375
# Hokusai - The Great Wave off Kanagawa-Tulips,217496.53125
# Hokusai - The Great Wave off Kanagawa-Tulips-color,217496.53125
# Aoyama - Detective Conan-Tulips,359463.0625
# Aoyama - Detective Conan-Tulips-color,359463.0625
# Monet - Haystack-Tulips,157767.1875
# Monet - Haystack-Tulips-color,157767.1875
# Monet - En Paysage dans l'ile Saint-Martin-Tulips,156203.5625
# Monet - En Paysage dans l'ile Saint-Martin-Tulips-color,156203.5625
# Monet - Camille Monet On Her Deathbed-Grand Portage MN,72198.2734375
# Monet - Camille Monet On Her Deathbed-Grand Portage MN-color,72198.2734375
# Picasso - The Dream-Grand Portage MN,153042.4375
# Picasso - The Dream-Grand Portage MN-color,153042.4375
# Rousseau - Myself-Grand Portage MN,80899.3125
# Rousseau - Myself-Grand Portage MN-color,80899.3125
# van Gogh - Starry Night-Grand Portage MN,115020.15625
# van Gogh - Starry Night-Grand Portage MN-color,115020.15625
# Gao Jianfu - Cotton Roses and Mandarin Ducks-Grand Portage MN,83458.8671875
# Gao Jianfu - Cotton Roses and Mandarin Ducks-Grand Portage MN-color,83458.8671875
# Qi Baishi - Lotus Flowers and Wild Duck-Grand Portage MN,106092.671875
# Qi Baishi - Lotus Flowers and Wild Duck-Grand Portage MN-color,106092.671875
# Hokusai - The Great Wave off Kanagawa-Grand Portage MN,161287.46875
# Hokusai - The Great Wave off Kanagawa-Grand Portage MN-color,161287.46875
# Aoyama - Detective Conan-Grand Portage MN,312971.5625
# Aoyama - Detective Conan-Grand Portage MN-color,312971.5625
# Monet - Haystack-Grand Portage MN,69542.171875
# Monet - Haystack-Grand Portage MN-color,69542.171875
# Monet - En Paysage dans l'ile Saint-Martin-Grand Portage MN,62420.7890625
# Monet - En Paysage dans l'ile Saint-Martin-Grand Portage MN-color,62420.7890625
# Monet - Camille Monet On Her Deathbed-Iceland.pn,108673.8125
# Monet - Camille Monet On Her Deathbed-Iceland.pn-color,108673.8125
# Picasso - The Dream-Iceland.pn,198875.921875
# Picasso - The Dream-Iceland.pn-color,198875.921875
# Rousseau - Myself-Iceland.pn,110229.8359375
# Rousseau - Myself-Iceland.pn-color,110229.8359375
# van Gogh - Starry Night-Iceland.pn,127328.1796875
# van Gogh - Starry Night-Iceland.pn-color,127328.1796875
# Gao Jianfu - Cotton Roses and Mandarin Ducks-Iceland.pn,127518.171875
# Gao Jianfu - Cotton Roses and Mandarin Ducks-Iceland.pn-color,127518.171875
# Qi Baishi - Lotus Flowers and Wild Duck-Iceland.pn,153224.640625
# Qi Baishi - Lotus Flowers and Wild Duck-Iceland.pn-color,153224.640625
# Hokusai - The Great Wave off Kanagawa-Iceland.pn,187020.375
# Hokusai - The Great Wave off Kanagawa-Iceland.pn-color,187020.375
# Aoyama - Detective Conan-Iceland.pn,321260.375
# Aoyama - Detective Conan-Iceland.pn-color,321260.375
# Monet - Haystack-Iceland.pn,118534.4375
# Monet - Haystack-Iceland.pn-color,118534.4375
# Monet - En Paysage dans l'ile Saint-Martin-Iceland.pn,108497.4765625
# Monet - En Paysage dans l'ile Saint-Martin-Iceland.pn-color,108497.4765625
# Monet - Camille Monet On Her Deathbed-yosemite,86181.9765625
# Monet - Camille Monet On Her Deathbed-yosemite-color,86181.9765625
# Picasso - The Dream-yosemite,162083.296875
# Picasso - The Dream-yosemite-color,162083.296875
# Rousseau - Myself-yosemite,90453.328125
# Rousseau - Myself-yosemite-color,90453.328125
# van Gogh - Starry Night-yosemite,98839.625
# van Gogh - Starry Night-yosemite-color,98839.625
# Gao Jianfu - Cotton Roses and Mandarin Ducks-yosemite,112601.1796875
# Gao Jianfu - Cotton Roses and Mandarin Ducks-yosemite-color,112601.1796875
# Qi Baishi - Lotus Flowers and Wild Duck-yosemite,129042.171875
# Qi Baishi - Lotus Flowers and Wild Duck-yosemite-color,129042.171875
# Hokusai - The Great Wave off Kanagawa-yosemite,171599.96875
# Hokusai - The Great Wave off Kanagawa-yosemite-color,171599.96875
# Aoyama - Detective Conan-yosemite,327309.84375
# Aoyama - Detective Conan-yosemite-color,327309.84375
# Monet - Haystack-yosemite,101288.6015625
# Monet - Haystack-yosemite-color,101288.6015625
# Monet - En Paysage dans l'ile Saint-Martin-yosemite,101747.296875
# Monet - En Paysage dans l'ile Saint-Martin-yosemite-color,101747.296875
# Monet - Camille Monet On Her Deathbed-seattle-morning.jpe,97755.0390625
# Monet - Camille Monet On Her Deathbed-seattle-morning.jpe-color,97755.0390625
# Picasso - The Dream-seattle-morning.jpe,159397.921875
# Picasso - The Dream-seattle-morning.jpe-color,159397.921875
# Rousseau - Myself-seattle-morning.jpe,92188.3046875
# Rousseau - Myself-seattle-morning.jpe-color,92188.3046875
# van Gogh - Starry Night-seattle-morning.jpe,123582.9375
# van Gogh - Starry Night-seattle-morning.jpe-color,123582.9375
# Gao Jianfu - Cotton Roses and Mandarin Ducks-seattle-morning.jpe,104423.125
# Gao Jianfu - Cotton Roses and Mandarin Ducks-seattle-morning.jpe-color,104423.125
# Qi Baishi - Lotus Flowers and Wild Duck-seattle-morning.jpe,117476.390625
# Qi Baishi - Lotus Flowers and Wild Duck-seattle-morning.jpe-color,117476.390625
# Hokusai - The Great Wave off Kanagawa-seattle-morning.jpe,151919.125
# Hokusai - The Great Wave off Kanagawa-seattle-morning.jpe-color,151919.125
# Aoyama - Detective Conan-seattle-morning.jpe,268276.09375
# Aoyama - Detective Conan-seattle-morning.jpe-color,268276.09375
# Monet - Haystack-seattle-morning.jpe,101381.28125
# Monet - Haystack-seattle-morning.jpe-color,101381.28125
# Monet - En Paysage dans l'ile Saint-Martin-seattle-morning.jpe,96127.390625
# Monet - En Paysage dans l'ile Saint-Martin-seattle-morning.jpe-color,96127.390625
# Monet - Camille Monet On Her Deathbed-octopus,83600.25
# Monet - Camille Monet On Her Deathbed-octopus-color,83600.25
# Picasso - The Dream-octopus,146374.359375
# Picasso - The Dream-octopus-color,146374.359375
# Rousseau - Myself-octopus,96550.890625
# Rousseau - Myself-octopus-color,96550.890625
# van Gogh - Starry Night-octopus,125832.0390625
# van Gogh - Starry Night-octopus-color,125832.0390625
# Gao Jianfu - Cotton Roses and Mandarin Ducks-octopus,91772.8671875
# Gao Jianfu - Cotton Roses and Mandarin Ducks-octopus-color,91772.8671875
# Qi Baishi - Lotus Flowers and Wild Duck-octopus,98267.328125
# Qi Baishi - Lotus Flowers and Wild Duck-octopus-color,98267.328125
# Hokusai - The Great Wave off Kanagawa-octopus,143643.53125
# Hokusai - The Great Wave off Kanagawa-octopus-color,143643.53125
# Aoyama - Detective Conan-octopus,288413.625
# Aoyama - Detective Conan-octopus-color,288413.625
# Monet - Haystack-octopus,92507.75
# Monet - Haystack-octopus-color,92507.75
# Monet - En Paysage dans l'ile Saint-Martin-octopus,86880.328125
# Monet - En Paysage dans l'ile Saint-Martin-octopus-color,86880.328125
# Monet - Camille Monet On Her Deathbed-octopus2,122172.6484375
# Monet - Camille Monet On Her Deathbed-octopus2-color,122172.6484375
# Picasso - The Dream-octopus2,166875.3125
# Picasso - The Dream-octopus2-color,166875.3125
# Rousseau - Myself-octopus2,110309.9140625
# Rousseau - Myself-octopus2-color,110309.9140625
# van Gogh - Starry Night-octopus2,117749.140625
# van Gogh - Starry Night-octopus2-color,117749.140625
# Gao Jianfu - Cotton Roses and Mandarin Ducks-octopus2,162174.78125
# Gao Jianfu - Cotton Roses and Mandarin Ducks-octopus2-color,162174.78125
# Qi Baishi - Lotus Flowers and Wild Duck-octopus2,196812.34375
# Qi Baishi - Lotus Flowers and Wild Duck-octopus2-color,196812.34375
# Hokusai - The Great Wave off Kanagawa-octopus2,178523.90625
# Hokusai - The Great Wave off Kanagawa-octopus2-color,178523.90625
# Aoyama - Detective Conan-octopus2,348215.5625
# Aoyama - Detective Conan-octopus2-color,348215.5625
# Monet - Haystack-octopus2,140732.21875
# Monet - Haystack-octopus2-color,140732.21875
# Monet - En Paysage dans l'ile Saint-Martin-octopus2,126288.890625
# Monet - En Paysage dans l'ile Saint-Martin-octopus2-color,126288.890625
# Monet - Camille Monet On Her Deathbed-octopus3,196781.53125
# Monet - Camille Monet On Her Deathbed-octopus3-color,196781.53125
# Picasso - The Dream-octopus3,222529.28125
# Picasso - The Dream-octopus3-color,222529.28125
# Rousseau - Myself-octopus3,163921.765625
# Rousseau - Myself-octopus3-color,163921.765625
# van Gogh - Starry Night-octopus3,170601.125
# van Gogh - Starry Night-octopus3-color,170601.125
# Gao Jianfu - Cotton Roses and Mandarin Ducks-octopus3,258948.265625
# Gao Jianfu - Cotton Roses and Mandarin Ducks-octopus3-color,258948.265625
# Qi Baishi - Lotus Flowers and Wild Duck-octopus3,327470.09375
# Qi Baishi - Lotus Flowers and Wild Duck-octopus3-color,327470.09375
# Hokusai - The Great Wave off Kanagawa-octopus3,243349.9375
# Hokusai - The Great Wave off Kanagawa-octopus3-color,243349.9375
# Aoyama - Detective Conan-octopus3,488049.71875
# Aoyama - Detective Conan-octopus3-color,488049.71875
# Monet - Haystack-octopus3,218953.875
# Monet - Haystack-octopus3-color,218953.875
# Monet - En Paysage dans l'ile Saint-Martin-octopus3,216865.015625
# Monet - En Paysage dans l'ile Saint-Martin-octopus3-color,216865.015625
# Monet - Camille Monet On Her Deathbed-octopus4,76341.21875
# Monet - Camille Monet On Her Deathbed-octopus4-color,76341.21875
# Picasso - The Dream-octopus4,154091.6875
# Picasso - The Dream-octopus4-color,154091.6875
# Rousseau - Myself-octopus4,110648.265625
# Rousseau - Myself-octopus4-color,110648.265625
# van Gogh - Starry Night-octopus4,119867.65625
# van Gogh - Starry Night-octopus4-color,119867.65625
# Gao Jianfu - Cotton Roses and Mandarin Ducks-octopus4,105230.375
# Gao Jianfu - Cotton Roses and Mandarin Ducks-octopus4-color,105230.375
# Qi Baishi - Lotus Flowers and Wild Duck-octopus4,117696.3125
# Qi Baishi - Lotus Flowers and Wild Duck-octopus4-color,117696.3125
# Hokusai - The Great Wave off Kanagawa-octopus4,160708.1875
# Hokusai - The Great Wave off Kanagawa-octopus4-color,160708.1875
# Aoyama - Detective Conan-octopus4,338720.53125
# Aoyama - Detective Conan-octopus4-color,338720.53125
# Monet - Haystack-octopus4,89333.65625
# Monet - Haystack-octopus4-color,89333.65625
# Monet - En Paysage dans l'ile Saint-Martin-octopus4,85222.9375
# Monet - En Paysage dans l'ile Saint-Martin-octopus4-color,85222.9375
